# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 616

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
        
         # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
                   'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | chicama
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | merke
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | adrar
# Processing Record 22 of Set 1 | klaksvik
# Processing Record 23 of Set 1 | mabama
# Processing Record 24 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | venado tuerto
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 1 | hendaye
# Processing Record 30 of Set 1 | moba
# Processing Record 31 of Set 1 | yibin
# Processing Record 32 of Set 1 | narsaq
# Processing Record 33 of Set 1 | yopal
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | alice springs
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | mehamn
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | asfi
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 1 | ladario
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | road town
# Processing Record 49 of Set 1 | turayf
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | sao felix do xingu
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | gazojak
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | vila franca do campo
# Processing Record 16 of Set 2 | lagoa
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | eregli
# Processing Record 19 of Set 2 | ozernovskiy
# Processing Record 20 of Set 2 | matara
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 2 | flinders
# Processing Record 24 of Set 2 | tallahassee
# Processing Record 25 of Set 2 | shache
# Processing Record 26 of Set 2 | onda
# Processing Record 27 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 2 | talaya
# Processing Record 29 of Set 2 | laredo
# Processing Record 30 of Set 2 | la baule-escoublac
# Processing Record 31 of Set 2 | ostrovnoy
# Processing Record 32 of Set 2 | jalu
# Processing Record 33 of Set 2 | kirakira
# Processing Record 34 of Set 2 | shenjiamen
# Processing Record 35 of Set 2 | avarua
# Processing Record 36 of Set 2 | merauke
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | denpasar
# Processing Record 39 of Set 2 | nelson bay
# Processing Record 40 of Set 2 | bac lieu
# Processing Record 41 of Set 2 | college
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | biltine
# Processing Record 45 of Set 2 | salym
# Processing Record 46 of Set 2 | honningsvag
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | sao joao do piaui
# Processing Record 49 of Set 2 | dingle
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | necochea
# Processing Record 4 of Set 3 | alugan
# Processing Record 5 of Set 3 | ballina
# Processing Record 6 of Set 3 | pontes e lacerda
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | carauari
# Processing Record 9 of Set 3 | pale
# Processing Record 10 of Set 3 | busselton
# Processing Record 11 of Set 3 | mataura
# Processing Record 12 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | veraval
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | tanout
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | nome
# Processing Record 19 of Set 3 | la ronge
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | korla
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | male
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | yar-sale
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | ikom
# Processing Record 28 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 29 of Set 3 | sisimiut
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 3 | north marysville
# City not found. Skipping...
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | csabacsud
# City not found. Skipping...
# Processing Record 35 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 3 | nanortalik
# Processing Record 37 of Set 3 | nioro
# Processing Record 38 of Set 3 | kristianstad
# Processing Record 39 of Set 3 | provideniya
# Processing Record 40 of Set 3 | verkhnyaya inta
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | bulgan
# Processing Record 43 of Set 3 | san rafael
# Processing Record 44 of Set 3 | newtownards
# Processing Record 45 of Set 3 | omsukchan
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 3 | canakkale
# Processing Record 50 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 4 | terrace
# Processing Record 2 of Set 4 | nemuro
# Processing Record 3 of Set 4 | baghdad
# Processing Record 4 of Set 4 | zyryanka
# Processing Record 5 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 4 | severo-kurilsk
# Processing Record 7 of Set 4 | flin flon
# Processing Record 8 of Set 4 | gat
# Processing Record 9 of Set 4 | husavik
# Processing Record 10 of Set 4 | sitka
# Processing Record 11 of Set 4 | carnarvon
# Processing Record 12 of Set 4 | faanui
# Processing Record 13 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 4 | puerto boyaca
# Processing Record 15 of Set 4 | khatanga
# Processing Record 16 of Set 4 | santander
# Processing Record 17 of Set 4 | hobyo
# Processing Record 18 of Set 4 | kavieng
# Processing Record 19 of Set 4 | czluchow
# Processing Record 20 of Set 4 | khorramshahr
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | broken hill
# Processing Record 23 of Set 4 | steinbach
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | xuanzhou
# Processing Record 26 of Set 4 | cetariu
# Processing Record 27 of Set 4 | huarmey
# Processing Record 28 of Set 4 | touros
# Processing Record 29 of Set 4 | teya
# Processing Record 30 of Set 4 | olafsvik
# Processing Record 31 of Set 4 | sekoma
# Processing Record 32 of Set 4 | rocha
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | palmas
# Processing Record 35 of Set 4 | rundu
# Processing Record 36 of Set 4 | zima
# Processing Record 37 of Set 4 | kampen
# Processing Record 38 of Set 4 | troitsko-pechorsk
# Processing Record 39 of Set 4 | la asuncion
# Processing Record 40 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 41 of Set 4 | marfino
# Processing Record 42 of Set 4 | lluta
# Processing Record 43 of Set 4 | marsh harbour
# Processing Record 44 of Set 4 | tautira
# Processing Record 45 of Set 4 | deputatskiy
# Processing Record 46 of Set 4 | tura
# Processing Record 47 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 4 | bekwai
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | mahebourg
# Processing Record 1 of Set 5 | northam
# Processing Record 2 of Set 5 | asilah
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | ponta do sol
# Processing Record 5 of Set 5 | dukat
# Processing Record 6 of Set 5 | lazaro cardenas
# Processing Record 7 of Set 5 | sorland
# Processing Record 8 of Set 5 | ayan
# Processing Record 9 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 5 | new norfolk
# Processing Record 11 of Set 5 | richards bay
# Processing Record 12 of Set 5 | kazbegi
# City not found. Skipping...
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | svetlyy
# Processing Record 15 of Set 5 | kaniama
# Processing Record 16 of Set 5 | koster
# Processing Record 17 of Set 5 | piacabucu
# Processing Record 18 of Set 5 | mayumba
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | sola
# Processing Record 22 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | manado
# Processing Record 25 of Set 5 | iquitos
# Processing Record 26 of Set 5 | sistranda
# Processing Record 27 of Set 5 | gayny
# Processing Record 28 of Set 5 | moncton
# Processing Record 29 of Set 5 | saskylakh
# Processing Record 30 of Set 5 | tucuman
# Processing Record 31 of Set 5 | tulum
# Processing Record 32 of Set 5 | geraldton
# Processing Record 33 of Set 5 | pemangkat
# Processing Record 34 of Set 5 | gornozavodsk
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | isabela
# Processing Record 37 of Set 5 | nuuk
# Processing Record 38 of Set 5 | porto novo
# Processing Record 39 of Set 5 | farmington
# Processing Record 40 of Set 5 | miquelon
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | buckeye
# Processing Record 43 of Set 5 | bandarbeyla
# Processing Record 44 of Set 5 | batu
# Processing Record 45 of Set 5 | asau
# Processing Record 46 of Set 5 | sibolga
# Processing Record 47 of Set 5 | copiapo
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | whitehorse
# Processing Record 50 of Set 5 | fernley
# Processing Record 1 of Set 6 | wasilla
# Processing Record 2 of Set 6 | sabya
# Processing Record 3 of Set 6 | hansot
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 6 of Set 6 | porto velho
# Processing Record 7 of Set 6 | banes
# Processing Record 8 of Set 6 | callaway
# Processing Record 9 of Set 6 | belyy yar
# Processing Record 10 of Set 6 | ostersund
# Processing Record 11 of Set 6 | teguldet
# Processing Record 12 of Set 6 | vacaria
# Processing Record 13 of Set 6 | fare
# Processing Record 14 of Set 6 | marrakesh
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | guilin
# Processing Record 17 of Set 6 | sabang
# Processing Record 18 of Set 6 | kununurra
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | yatou
# Processing Record 21 of Set 6 | grindavik
# Processing Record 22 of Set 6 | faya
# Processing Record 23 of Set 6 | namibe
# Processing Record 24 of Set 6 | krasnoselkup
# Processing Record 25 of Set 6 | ossora
# Processing Record 26 of Set 6 | eyl
# Processing Record 27 of Set 6 | tecpan
# Processing Record 28 of Set 6 | arona
# Processing Record 29 of Set 6 | leningradskiy
# Processing Record 30 of Set 6 | pitea
# Processing Record 31 of Set 6 | inuvik
# Processing Record 32 of Set 6 | takoradi
# Processing Record 33 of Set 6 | kidal
# Processing Record 34 of Set 6 | nouadhibou
# Processing Record 35 of Set 6 | lata
# Processing Record 36 of Set 6 | vila velha
# Processing Record 37 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 6 | irbit
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | kismayo
# Processing Record 41 of Set 6 | esperance
# Processing Record 42 of Set 6 | rovaniemi
# Processing Record 43 of Set 6 | ulladulla
# Processing Record 44 of Set 6 | cayenne
# Processing Record 45 of Set 6 | ayagoz
# Processing Record 46 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 6 | hervey bay
# Processing Record 48 of Set 6 | salinas
# Processing Record 49 of Set 6 | araouane
# Processing Record 50 of Set 6 | ardahan
# Processing Record 1 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | neryungri
# Processing Record 3 of Set 7 | torbay
# Processing Record 4 of Set 7 | ushibuka
# Processing Record 5 of Set 7 | ust-kuyga
# Processing Record 6 of Set 7 | qaqortoq
# Processing Record 7 of Set 7 | sao paulo de olivenca
# Processing Record 8 of Set 7 | syasstroy
# Processing Record 9 of Set 7 | grand baie
# Processing Record 10 of Set 7 | weihai
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | medicine hat
# Processing Record 13 of Set 7 | peleduy
# Processing Record 14 of Set 7 | jawhar
# Processing Record 15 of Set 7 | clyde river
# Processing Record 16 of Set 7 | praia
# Processing Record 17 of Set 7 | tancheng
# Processing Record 18 of Set 7 | tateyama
# Processing Record 19 of Set 7 | boca do acre
# Processing Record 20 of Set 7 | verkhnevilyuysk
# Processing Record 21 of Set 7 | zhezkazgan
# Processing Record 22 of Set 7 | morgan city
# Processing Record 23 of Set 7 | namatanai
# Processing Record 24 of Set 7 | turki
# Processing Record 25 of Set 7 | kabinda
# Processing Record 26 of Set 7 | san jose
# Processing Record 27 of Set 7 | shubarkuduk
# Processing Record 28 of Set 7 | lompoc
# Processing Record 29 of Set 7 | andenes
# Processing Record 30 of Set 7 | mayo
# Processing Record 31 of Set 7 | gizo
# Processing Record 32 of Set 7 | dolores
# Processing Record 33 of Set 7 | hamilton
# Processing Record 34 of Set 7 | naugarzan
# City not found. Skipping...
# Processing Record 35 of Set 7 | fukuma
# Processing Record 36 of Set 7 | mataram
# Processing Record 37 of Set 7 | te anau
# Processing Record 38 of Set 7 | gao
# Processing Record 39 of Set 7 | honiara
# Processing Record 40 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 7 | lugo
# Processing Record 42 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 43 of Set 7 | lucapa
# Processing Record 44 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 7 | santiago de cao
# Processing Record 46 of Set 7 | corpus christi
# Processing Record 47 of Set 7 | kalmunai
# Processing Record 48 of Set 7 | minna
# Processing Record 49 of Set 7 | maniitsoq
# Processing Record 50 of Set 7 | tiksi
# Processing Record 1 of Set 8 | mahajanga
# Processing Record 2 of Set 8 | vanimo
# Processing Record 3 of Set 8 | tabou
# Processing Record 4 of Set 8 | lorengau
# Processing Record 5 of Set 8 | coalcoman
# City not found. Skipping...
# Processing Record 6 of Set 8 | katobu
# Processing Record 7 of Set 8 | morondava
# Processing Record 8 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 9 of Set 8 | oistins
# Processing Record 10 of Set 8 | rivera
# Processing Record 11 of Set 8 | moose factory
# Processing Record 12 of Set 8 | taoudenni
# Processing Record 13 of Set 8 | samfya
# Processing Record 14 of Set 8 | aksu
# Processing Record 15 of Set 8 | along
# Processing Record 16 of Set 8 | bjala
# City not found. Skipping...
# Processing Record 17 of Set 8 | sandi
# Processing Record 18 of Set 8 | ola
# Processing Record 19 of Set 8 | marystown
# Processing Record 20 of Set 8 | ketchikan
# Processing Record 21 of Set 8 | nguruka
# Processing Record 22 of Set 8 | hambantota
# Processing Record 23 of Set 8 | envira
# Processing Record 24 of Set 8 | catumbela
# Processing Record 25 of Set 8 | boende
# Processing Record 26 of Set 8 | leh
# Processing Record 27 of Set 8 | skjervoy
# Processing Record 28 of Set 8 | yakeshi
# Processing Record 29 of Set 8 | lavrentiya
# Processing Record 30 of Set 8 | sungurlu
# Processing Record 31 of Set 8 | talnakh
# Processing Record 32 of Set 8 | rio gallegos
# Processing Record 33 of Set 8 | makakilo city
# Processing Record 34 of Set 8 | mount gambier
# Processing Record 35 of Set 8 | oum hadjer
# Processing Record 36 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 8 | bilsi
# Processing Record 38 of Set 8 | sinnamary
# Processing Record 39 of Set 8 | dangriga
# Processing Record 40 of Set 8 | dymer
# Processing Record 41 of Set 8 | baykit
# Processing Record 42 of Set 8 | gidole
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | sept-iles
# Processing Record 45 of Set 8 | ahuimanu
# Processing Record 46 of Set 8 | cartagena del chaira
# Processing Record 47 of Set 8 | manacapuru
# Processing Record 48 of Set 8 | manzhouli
# Processing Record 49 of Set 8 | maragogi
# Processing Record 50 of Set 8 | craig
# Processing Record 1 of Set 9 | taonan
# Processing Record 2 of Set 9 | paita
# Processing Record 3 of Set 9 | decatur
# Processing Record 4 of Set 9 | matagami
# Processing Record 5 of Set 9 | martapura
# Processing Record 6 of Set 9 | turukhansk
# Processing Record 7 of Set 9 | port hedland
# Processing Record 8 of Set 9 | antofagasta
# Processing Record 9 of Set 9 | pevek
# Processing Record 10 of Set 9 | kiunga
# Processing Record 11 of Set 9 | mineral wells
# Processing Record 12 of Set 9 | san policarpo
# Processing Record 13 of Set 9 | vila
# Processing Record 14 of Set 9 | raudeberg
# Processing Record 15 of Set 9 | roald
# Processing Record 16 of Set 9 | aklavik
# Processing Record 17 of Set 9 | saint-pierre
# Processing Record 18 of Set 9 | talara
# Processing Record 19 of Set 9 | gejiu
# Processing Record 20 of Set 9 | sal rei
# Processing Record 21 of Set 9 | abu samrah
# Processing Record 22 of Set 9 | teknaf
# Processing Record 23 of Set 9 | usinsk
# Processing Record 24 of Set 9 | havoysund
# Processing Record 25 of Set 9 | ust-tsilma
# Processing Record 26 of Set 9 | portsmouth
# Processing Record 27 of Set 9 | sobolevo
# Processing Record 28 of Set 9 | ornskoldsvik
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | samarai
# Processing Record 31 of Set 9 | kolpashevo
# Processing Record 32 of Set 9 | pangnirtung
# Processing Record 33 of Set 9 | cap-aux-meules
# Processing Record 34 of Set 9 | ust-ishim
# Processing Record 35 of Set 9 | bengkulu
# Processing Record 36 of Set 9 | tilichiki
# Processing Record 37 of Set 9 | coihaique
# Processing Record 38 of Set 9 | sumbe
# Processing Record 39 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 9 | nongstoin
# Processing Record 41 of Set 9 | biak
# Processing Record 42 of Set 9 | korcula
# Processing Record 43 of Set 9 | tuy hoa
# Processing Record 44 of Set 9 | tutoia
# Processing Record 45 of Set 9 | williams lake
# Processing Record 46 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 9 | tumpat
# Processing Record 48 of Set 9 | mao
# Processing Record 49 of Set 9 | katima mulilo
# Processing Record 50 of Set 9 | olot
# Processing Record 1 of Set 10 | nichinan
# Processing Record 2 of Set 10 | catuday
# Processing Record 3 of Set 10 | sao jose da coroa grande
# Processing Record 4 of Set 10 | grand gaube
# Processing Record 5 of Set 10 | sakakah
# Processing Record 6 of Set 10 | hay river
# Processing Record 7 of Set 10 | oriximina
# Processing Record 8 of Set 10 | suclayin
# Processing Record 9 of Set 10 | abdulino
# Processing Record 10 of Set 10 | camacha
# Processing Record 11 of Set 10 | oktyabrskoye
# Processing Record 12 of Set 10 | habiganj
# Processing Record 13 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 10 | walvis bay
# Processing Record 15 of Set 10 | santa cruz
# Processing Record 16 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 17 of Set 10 | fort nelson
# Processing Record 18 of Set 10 | vila do maio
# Processing Record 19 of Set 10 | arkhangelsk
# Processing Record 20 of Set 10 | mount isa
# Processing Record 21 of Set 10 | qobustan
# Processing Record 22 of Set 10 | luganville
# Processing Record 23 of Set 10 | kalbay
# Processing Record 24 of Set 10 | alibag
# Processing Record 25 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 26 of Set 10 | port macquarie
# Processing Record 27 of Set 10 | banepa
# Processing Record 28 of Set 10 | fukue
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | shimoda
# Processing Record 31 of Set 10 | buluang
# Processing Record 32 of Set 10 | yuci
# Processing Record 33 of Set 10 | vestmannaeyjar
# Processing Record 34 of Set 10 | loandjili
# Processing Record 35 of Set 10 | cilegon
# Processing Record 36 of Set 10 | juruti
# Processing Record 37 of Set 10 | satuk
# Processing Record 38 of Set 10 | nizhniy kuranakh
# Processing Record 39 of Set 10 | hauterive
# Processing Record 40 of Set 10 | gubkinskiy
# Processing Record 41 of Set 10 | banda aceh
# Processing Record 42 of Set 10 | kargat
# Processing Record 43 of Set 10 | miri
# Processing Record 44 of Set 10 | nicoya
# Processing Record 45 of Set 10 | oskaloosa
# Processing Record 46 of Set 10 | acapulco
# Processing Record 47 of Set 10 | shalakusha
# Processing Record 48 of Set 10 | belaya gora
# Processing Record 49 of Set 10 | kilindoni
# Processing Record 50 of Set 10 | vite
# Processing Record 1 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | kapoeta
# Processing Record 3 of Set 11 | arnold
# Processing Record 4 of Set 11 | naryan-mar
# Processing Record 5 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 6 of Set 11 | bilma
# Processing Record 7 of Set 11 | zemio
# Processing Record 8 of Set 11 | khash
# Processing Record 9 of Set 11 | banda
# Processing Record 10 of Set 11 | terney
# Processing Record 11 of Set 11 | champerico
# Processing Record 12 of Set 11 | watsa
# Processing Record 13 of Set 11 | koson
# Processing Record 14 of Set 11 | veseloyarsk
# Processing Record 15 of Set 11 | pisco
# Processing Record 16 of Set 11 | trairi
# Processing Record 17 of Set 11 | port hardy
# Processing Record 18 of Set 11 | mantua
# Processing Record 19 of Set 11 | pfullendorf
# Processing Record 20 of Set 11 | arkhangelskoye
# Processing Record 21 of Set 11 | pakxan
# Processing Record 22 of Set 11 | ca mau
# Processing Record 23 of Set 11 | wukari
# Processing Record 24 of Set 11 | el transito
# Processing Record 25 of Set 11 | kieta
# Processing Record 26 of Set 11 | altar
# Processing Record 27 of Set 11 | bonthe
# Processing Record 28 of Set 11 | ust-omchug
# Processing Record 29 of Set 11 | belmonte
# Processing Record 30 of Set 11 | peterhead
# Processing Record 31 of Set 11 | kuznechnoye
# Processing Record 32 of Set 11 | vardo
# Processing Record 33 of Set 11 | porto belo
# Processing Record 34 of Set 11 | tres rios
# Processing Record 35 of Set 11 | pamfila
# Processing Record 36 of Set 11 | ilo
# Processing Record 37 of Set 11 | tiarei
# Processing Record 38 of Set 11 | beloha
# Processing Record 39 of Set 11 | havre
# Processing Record 40 of Set 11 | north platte
# Processing Record 41 of Set 11 | chiredzi
# Processing Record 42 of Set 11 | torrington
# Processing Record 43 of Set 11 | hofn
# Processing Record 44 of Set 11 | chingirlau
# Processing Record 45 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 11 | bodden town
# Processing Record 47 of Set 11 | kangaatsiaq
# Processing Record 48 of Set 11 | anadyr
# Processing Record 49 of Set 11 | bolgar
# Processing Record 50 of Set 11 | cervo
# Processing Record 1 of Set 12 | verkhoyansk
# Processing Record 2 of Set 12 | stanger
# Processing Record 3 of Set 12 | fairview
# Processing Record 4 of Set 12 | portland
# Processing Record 5 of Set 12 | shaikhpura
# Processing Record 6 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 12 | cedar city
# Processing Record 8 of Set 12 | nizwa
# Processing Record 9 of Set 12 | vestmanna
# Processing Record 10 of Set 12 | zhigansk
# Processing Record 11 of Set 12 | suratgarh
# Processing Record 12 of Set 12 | sicuani
# Processing Record 13 of Set 12 | druzhba
# Processing Record 14 of Set 12 | mulchen
# Processing Record 15 of Set 12 | taltal
# Processing Record 16 of Set 12 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 17 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 12 | trindade
# Processing Record 19 of Set 12 | sur
# Processing Record 20 of Set 12 | gambo
# Processing Record 21 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 12 | monrovia
# Processing Record 23 of Set 12 | buraydah
# Processing Record 24 of Set 12 | savannah bight
# Processing Record 25 of Set 12 | bahia blanca
# Processing Record 26 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 27 of Set 12 | puerto narino
# Processing Record 28 of Set 12 | markova
# Processing Record 29 of Set 12 | novyy urengoy
# Processing Record 30 of Set 12 | post falls
# Processing Record 31 of Set 12 | dromolaxia
# Processing Record 32 of Set 12 | ereymentau
# Processing Record 33 of Set 12 | monteagudo
# Processing Record 34 of Set 12 | avera
# Processing Record 35 of Set 12 | goldsboro
# Processing Record 36 of Set 12 | zmievka
# City not found. Skipping...
# Processing Record 37 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 38 of Set 12 | vaasa
# Processing Record 39 of Set 12 | preobrazheniye
# Processing Record 40 of Set 12 | gamba
# Processing Record 41 of Set 12 | puteyets
# Processing Record 42 of Set 12 | kapuskasing
# Processing Record 43 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 44 of Set 12 | dunedin
# Processing Record 45 of Set 12 | hatfield
# Processing Record 46 of Set 12 | betare oya
# Processing Record 47 of Set 12 | labuhan
# Processing Record 48 of Set 12 | boyolangu
# Processing Record 49 of Set 12 | mawlaik
# Processing Record 50 of Set 12 | pacific grove
# Processing Record 1 of Set 13 | yulara
# Processing Record 2 of Set 13 | matamoros
# Processing Record 3 of Set 13 | todos santos
# Processing Record 4 of Set 13 | cap malheureux
# Processing Record 5 of Set 13 | mersing
# Processing Record 6 of Set 13 | conde
# Processing Record 7 of Set 13 | paramonga
# Processing Record 8 of Set 13 | peace river
# Processing Record 9 of Set 13 | kaohsiung
# Processing Record 10 of Set 13 | stykkisholmur
# Processing Record 11 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 12 of Set 13 | kigonsera
# Processing Record 13 of Set 13 | dombarovskiy
# Processing Record 14 of Set 13 | jipijapa
# Processing Record 15 of Set 13 | bilibino
# Processing Record 16 of Set 13 | conceicao da barra
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 559

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City      Lat       Lng  Max Temp Current Description  \
# 0                     atuona  -9.8000 -139.0333     77.45          light rain
# 1                  hithadhoo  -0.6000   73.0833     84.42       broken clouds
# 2               punta arenas -53.1500  -70.9167     39.11    scattered clouds
# 3                     barrow  71.2906 -156.7887     19.42       broken clouds
# 4                    rikitea -23.1203 -134.9692     76.77    scattered clouds
# 5  petropavlovsk-kamchatskiy  53.0452  158.6483     39.90     overcast clouds
# 6                   tasiilaq  65.6145  -37.6368     35.76     overcast clouds
# 7               saint george  37.1041 -113.5841     65.25           clear sky
# 8                     hobart -42.8794  147.3294     45.01           clear sky
# 9                      vaini -21.2000 -175.2000     73.56          few clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.42            0.0        80          24       15.73      PF
# 1           0.00            0.0        76          69       18.90      MV
# 2           0.00            0.0        80          34       27.02      CL
# 3           0.00            0.0        86          75        9.22      US
# 4           0.00            0.0        79          28       19.51      PF
# 5           0.00            0.0        93         100        6.73      RU
# 6           0.00            0.0        67         100        6.02      GL
# 7           0.00            0.0        19           0        4.61      US
# 8           0.00            0.0        85           0        0.00      AU
# 9           0.00            0.0        88          20       10.36      TO

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description', 
                    'Rain (inches)', 'Snow (inches)']

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                     atuona      PF  -9.8000 -139.0333     77.45        80
# 1                  hithadhoo      MV  -0.6000   73.0833     84.42        76
# 2               punta arenas      CL -53.1500  -70.9167     39.11        80
# 3                     barrow      US  71.2906 -156.7887     19.42        86
# 4                    rikitea      PF -23.1203 -134.9692     76.77        79
# 5  petropavlovsk-kamchatskiy      RU  53.0452  158.6483     39.90        93
# 6                   tasiilaq      GL  65.6145  -37.6368     35.76        67
# 7               saint george      US  37.1041 -113.5841     65.25        19
# 8                     hobart      AU -42.8794  147.3294     45.01        85
# 9                      vaini      TO -21.2000 -175.2000     73.56        88
#
#    Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0          24       15.73          light rain           0.42            0.0
# 1          69       18.90       broken clouds           0.00            0.0
# 2          34       27.02    scattered clouds           0.00            0.0
# 3          75        9.22       broken clouds           0.00            0.0
# 4          28       19.51    scattered clouds           0.00            0.0
# 5         100        6.73     overcast clouds           0.00            0.0
# 6         100        6.02     overcast clouds           0.00            0.0
# 7           0        4.61           clear sky           0.00            0.0
# 8           0        0.00           clear sky           0.00            0.0
# 9          20       10.36          few clouds           0.00            0.0

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)'] > 0]
raining_cities.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       atuona      PF  -9.8000 -139.0333     77.45        80          24
# 20    klaksvik      FO  62.2266   -6.5890     49.12        98         100
# 26        moba      CN  33.2288  105.0179     51.06        87         100
# 27       yibin      CN  28.7667  104.6238     81.57        63         100
# 31  georgetown      MY   5.4112  100.3354     87.73        70          20
#
#     Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        15.73          light rain           0.42            0.0
# 20       20.04          light rain           0.17            0.0
# 26        7.18       moderate rain           1.15            0.0
# 27        3.02          light rain           0.21            0.0
# 31       10.36       moderate rain           3.16            0.0

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)'] > 0]
snowing_cities
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 34        mehamn      NO  71.0357   27.8492     29.86        94         100
# 106         nome      US  64.5011 -165.4064     32.11        93         100
# 122  provideniya      RU  64.3833 -173.3000     30.72        99         100
# 156         teya      RU  60.3778   92.6267     27.00        79         100
# 239       vostok      RU  46.4856  135.8833     34.36        88         100
# 339   lavrentiya      RU  65.5833 -171.0000     29.55        98         100
# 413    hay river      CA  60.8156 -115.7999     33.46        99         100
# 510     zhigansk      RU  66.7697  123.3711     33.69        99         100
# 557     bilibino      RU  68.0546  166.4372     24.13        97         100
#
#      Wind Speed Current Description  Rain (inches)  Snow (inches)
# 34        10.51          light snow            0.0           0.12
# 106       14.97                mist            0.0           0.25
# 122       10.13                snow            0.0           1.07
# 156        9.19          light snow            0.0           0.11
# 239        4.43          light snow            0.0           0.12
# 339        6.31                snow            0.0           1.40
# 413       10.16                snow            0.0           0.58
# 510        9.13          light snow            0.0           0.31
# 557        2.66          light snow            0.0           0.21

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
